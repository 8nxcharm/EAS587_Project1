# %%
import pandas as pd

df = pd.read_parquet("C:\Users\aidan\Desktop\EAS 587 Semester Project\yellow_tripdata_2024-06.parquet")
print(df.head(10))
# Out:
#   Cell In[2], line 3
#     df = pd.read_parquet("C:\Users\aidan\Desktop\EAS 587 Semester Project\yellow_tripdata_2024-06.parquet")
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
